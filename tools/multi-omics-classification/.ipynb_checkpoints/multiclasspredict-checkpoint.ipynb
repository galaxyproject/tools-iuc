# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.metrics import (roc_curve, auc, roc_auc_score, 
                             precision_recall_fscore_support)
from sklearn.model_selection import (train_test_split, GridSearchCV, 
                                     KFold, StratifiedKFold, cross_val_score, 
                                     cross_val_predict)
from sklearn.preprocessing import label_binarize, LabelEncoder, LabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import (SelectKBest, f_classif, VarianceThreshold, 
                                       SelectFromModel)
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.datasets import load_iris
import itertools

from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import copy

# %% [markdown]
# # OvO and OvR prediction function

# %%
from sklearn.preprocessing import LabelEncoder, LabelBinarizer
from sklearn.model_selection import StratifiedKFold, cross_val_predict, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
import numpy as np
import itertools

def split_classes(X, y):
    return {
        (c1, c2): (X[(y == c1) | (y == c2)], y[(y == c1) | (y == c2)])
        for c1, c2 in itertools.combinations(np.unique(y), 2)
    }

def ovo_and_ova_multiclass_auc(X, y, base_clf, p_grid, random_state):
    results = {}
    le = LabelEncoder()
    y = le.fit_transform(y)
    class_names = le.classes_

    # Stratified K-Folds
    inner_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
    outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

    ####################
    # One-vs-Rest Classification
    ####################
    print("Performing One vs Rest classification")
    ovr_clf = GridSearchCV(
        estimator=OneVsRestClassifier(base_clf),
        param_grid=p_grid,
        cv=inner_cv,
        scoring="roc_auc_ovr"
    )
    y_score = cross_val_predict(ovr_clf, X, y, cv=outer_cv, method="predict_proba")

    # Calculate AUC for each class
    y_bin = LabelBinarizer().fit_transform(y)
    ovr_auc = roc_auc_score(y_bin, y_score, multi_class="ovr", average=None)
    for idx, auc_val in enumerate(ovr_auc):
        print(f"AUC for class '{class_names[idx]}': {auc_val:.4f}")
        results[f"{class_names[idx]} vs Rest"] = auc_val

    # Calculate macro and micro AUC for OvR
    macro_ovr_auc = roc_auc_score(y_bin, y_score, multi_class="ovr", average="macro")
    micro_ovr_auc = roc_auc_score(y_bin, y_score, multi_class="ovr", average="micro")
    results["OvR Macro AUC"] = macro_ovr_auc
    results["OvR Micro AUC"] = micro_ovr_auc
    print(f"Macro AUC (OvR): {macro_ovr_auc:.4f}")
    print(f"Micro AUC (OvR): {micro_ovr_auc:.4f}")

    ####################
    # One-vs-One Classification
    ####################
    print("Performing One vs One classification")
    ovo_auc = {}
    class_pairs = split_classes(X, y)

    for (c1, c2), (X_subset, y_subset) in class_pairs.items():
        ovo_clf = GridSearchCV(
            estimator=base_clf,
            param_grid={k.replace("estimator__", ""): v for k, v in p_grid.items()},
            cv=inner_cv,
            scoring="roc_auc"
        )
        y_score = cross_val_predict(ovo_clf, X_subset, y_subset, cv=outer_cv, method="predict_proba")
        y_binary = (y_subset == c2).astype(int)
        fpr, tpr, _ = roc_curve(y_binary, y_score[:, 1])
        auc_val = auc(fpr, tpr)

        # Decode labels
        results[f"{le.inverse_transform([c1])[0]} vs {le.inverse_transform([c2])[0]}"] = auc_val
        ovo_auc[(c1, c2)] = auc_val

    # Calculate macro and micro AUC for OvO
    macro_ovo_auc = np.mean(list(ovo_auc.values()))  # Macro: Average AUC over all class pairs
    micro_ovo_auc = roc_auc_score(y, cross_val_predict(base_clf, X, y, cv=outer_cv, method="predict_proba"), multi_class="ovo", average="micro")  # Direct micro AUC for OvO
    results["OvO Macro AUC"] = macro_ovo_auc
    results["OvO Micro AUC"] = micro_ovo_auc
    print(f"Macro AUC (OvO): {macro_ovo_auc:.4f}")
    print(f"Micro AUC (OvO): {micro_ovo_auc:.4f}")

    return results

# %%
from sklearn.datasets import make_classification
import pandas as pd

# Generate a synthetic dataset
X, y = make_classification(
    n_samples=150,  # Number of samples
    n_features=1000,   # Total number of features
    n_informative=20,  # Number of informative features
    n_redundant=200,    # Number of redundant features
    n_classes=3,       # Number of target classes
    random_state=42    # For reproducibility
)

# Convert to DataFrame
X = pd.DataFrame(X)
y = pd.Series(y, name="target")

# %%
seed_results = {}

seeds = [1,2,3]
ks = [10,100]

for seed in seeds:
    ks_results = {}
    for k in ks:

        print(f"CV for seed {seed} and {k} features")

        # Define the classifier
        classifier = RandomForestClassifier(random_state=seed)

        # Create a Random Forest Classifier
        rf = RandomForestClassifier(n_estimators=100, random_state=seed)

        # Create a SelectFromModel using the Random Forest Classifier
        selector = SelectFromModel(rf, max_features = k)

        # Create a pipeline with feature selection and classification
        pipeline = Pipeline(steps=[
            ('feature_selection', selector),
            ('classification', rf)
        ])

        # Parameter grid for RandomForestClassifier
        p_grid = {
            "estimator__classification__n_estimators": [100],          # Number of trees in the forest
            "estimator__classification__max_features": ["sqrt"],       # Feature selection strategy
            "estimator__classification__criterion": ["entropy"],       # Split criterion
            "estimator__classification__min_samples_leaf": [3],        # Minimum samples per leaf
        }

        ###########################
            
        results = ovo_and_ova_multiclass_auc(X,y,pipeline, p_grid, random_state=seed)

        print(results)

        ks_results[k] = results

    seed_results[seed] = copy.copy(ks_results)
# Out:
# CV for seed 1 and 10 features
# Performing One vs Rest classification
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 37
#      28 p_grid = {
#      29     "estimator__classification__n_estimators": [100],          # Number of trees in the forest
#      30     "estimator__classification__max_features": ["sqrt"],       # Feature selection strategy
#      31     "estimator__classification__criterion": ["entropy"],       # Split criterion
#      32     "estimator__classification__min_samples_leaf": [3],        # Minimum samples per leaf
#      33 }
#      35 ###########################
# ---> 37 results = ovo_and_ova_multiclass_auc(X,y,pipeline, p_grid, random_state=seed)
#      39 print(results)
#      41 ks_results[k] = results
#
# Cell In[4], line 34, in ovo_and_ova_multiclass_auc(X, y, base_clf, p_grid, random_state)
#      27 print("Performing One vs Rest classification")
#      28 ovr_clf = GridSearchCV(
#      29     estimator=OneVsRestClassifier(base_clf),
#      30     param_grid=p_grid,
#      31     cv=inner_cv,
#      32     scoring="roc_auc_ovr"
#      33 )
# ---> 34 y_score = cross_val_predict(ovr_clf, X, y, cv=outer_cv, method="predict_proba")
#      36 # Calculate AUC for each class
#      37 y_bin = LabelBinarizer().fit_transform(y)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:1247, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, params, pre_dispatch, method)
#    1244 # We clone the estimator to make sure that all the folds are
#    1245 # independent, and that it is pickle-able.
#    1246 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# -> 1247 predictions = parallel(
#    1248     delayed(_fit_and_predict)(
#    1249         clone(estimator),
#    1250         X,
#    1251         y,
#    1252         train,
#    1253         test,
#    1254         routed_params.estimator.fit,
#    1255         method,
#    1256     )
#    1257     for train, test in splits
#    1258 )
#    1260 inv_test_indices = np.empty(len(test_indices), dtype=int)
#    1261 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:1332, in _fit_and_predict(estimator, X, y, train, test, fit_params, method)
#    1330     estimator.fit(X_train, **fit_params)
#    1331 else:
# -> 1332     estimator.fit(X_train, y_train, **fit_params)
#    1333 func = getattr(estimator, method)
#    1334 predictions = func(X_test)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/multiclass.py:376, in OneVsRestClassifier.fit(self, X, y, **fit_params)
#     372 columns = (col.toarray().ravel() for col in Y.T)
#     373 # In cases where individual estimators are very fast to train setting
#     374 # n_jobs > 1 in can results in slower performance due to the overhead
#     375 # of spawning threads.  See joblib issue #112.
# --> 376 self.estimators_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     377     delayed(_fit_binary)(
#     378         self.estimator,
#     379         X,
#     380         column,
#     381         fit_params=routed_params.estimator.fit,
#     382         classes=[
#     383             "not %s" % self.label_binarizer_.classes_[i],
#     384             self.label_binarizer_.classes_[i],
#     385         ],
#     386     )
#     387     for i, column in enumerate(columns)
#     388 )
#     390 if hasattr(self.estimators_[0], "n_features_in_"):
#     391     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/multiclass.py:96, in _fit_binary(estimator, X, y, fit_params, classes)
#      94 else:
#      95     estimator = clone(estimator)
# ---> 96     estimator.fit(X, y, **fit_params)
#      97 return estimator
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/pipeline.py:654, in Pipeline.fit(self, X, y, **params)
#     647     raise ValueError(
#     648         "The `transform_input` parameter can only be set if metadata "
#     649         "routing is enabled. You can enable metadata routing using "
#     650         "`sklearn.set_config(enable_metadata_routing=True)`."
#     651     )
#     653 routed_params = self._check_method_params(method="fit", props=params)
# --> 654 Xt = self._fit(X, y, routed_params, raw_params=params)
#     655 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     656     if self._final_estimator != "passthrough":
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/pipeline.py:588, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     581 # Fit or load from cache the current transformer
#     582 step_params = self._get_metadata_for_step(
#     583     step_idx=step_idx,
#     584     step_params=routed_params[name],
#     585     all_params=raw_params,
#     586 )
# --> 588 X, fitted_transformer = fit_transform_one_cached(
#     589     cloned_transformer,
#     590     X,
#     591     y,
#     592     weight=None,
#     593     message_clsname="Pipeline",
#     594     message=self._log_message(step_idx),
#     595     params=step_params,
#     596 )
#     597 # Replace the transformer of the step with the fitted
#     598 # transformer. This is necessary when loading the transformer
#     599 # from the cache.
#     600 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:921, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     918     return self.fit(X, **fit_params).transform(X)
#     919 else:
#     920     # fit method of arity 2 (supervised transformation)
# --> 921     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/feature_selection/_from_model.py:372, in SelectFromModel.fit(self, X, y, **fit_params)
#     369     else:
#     370         # TODO(SLEP6): remove when metadata routing cannot be disabled.
#     371         self.estimator_ = clone(self.estimator)
# --> 372         self.estimator_.fit(X, y, **fit_params)
#     374 if hasattr(self.estimator_, "feature_names_in_"):
#     375     self.feature_names_in_ = self.estimator_.feature_names_in_
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/utils/parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:176, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     173 else:
#     174     curr_sample_weight = sample_weight.copy()
# --> 176 indices = _generate_sample_indices(
#     177     tree.random_state, n_samples, n_samples_bootstrap
#     178 )
#     179 sample_counts = np.bincount(indices, minlength=n_samples)
#     180 curr_sample_weight *= sample_counts
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:130, in _generate_sample_indices(random_state, n_samples, n_samples_bootstrap)
#     126 """
#     127 Private function used to _parallel_build_trees function."""
#     129 random_instance = check_random_state(random_state)
# --> 130 sample_indices = random_instance.randint(
#     131     0, n_samples, n_samples_bootstrap, dtype=np.int32
#     132 )
#     134 return sample_indices
#
# File numpy/random/mtrand.pyx:794, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:1406, in numpy.random._bounded_integers._rand_int32()
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3445, in prod(a, axis, dtype, out, keepdims, initial, where)
#    3328 @array_function_dispatch(_prod_dispatcher)
#    3329 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    3330          initial=np._NoValue, where=np._NoValue):
#    3331     """
#    3332     Return the product of array elements over a given axis.
#    3333
#    (...)
#    3443     10
#    3444     """
# -> 3445     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3446                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/miniconda3/envs/planemo-env/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:77, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      75     reduction = getattr(obj, method)
#      76 except AttributeError:
# ---> 77     pass
#      78 else:
#      79     # This branch is needed for reductions like any which don't
#      80     # support a dtype.
#      81     if dtype is not None:
#
# KeyboardInterrupt:

# %%
# Flatten the nested dictionary into a DataFrame
df = pd.DataFrame(
    {(outer_key, inner_key): values for outer_key, inner_dict in seed_results.items() for inner_key, values in inner_dict.items()}
).T

# Set multi-level index names for clarity
df.index.names = ['Seed', 'Features (k)']

# Display the DataFrame
print(df)
# Out:
#                    0 vs Rest  1 vs Rest  2 vs Rest  0 vs 1  0 vs 2  1 vs 2
# Seed Features (k)
# 1    2                   1.0     0.9858     0.9858     1.0     1.0  0.9736
#      3                   1.0     0.9858     0.9858     1.0     1.0  0.9736
# 2    2                   1.0     0.9894     0.9894     1.0     1.0  0.9768
#      3                   1.0     0.9894     0.9894     1.0     1.0  0.9768
# 3    2                   1.0     0.9787     0.9687     1.0     1.0  0.9512
#      3                   1.0     0.9787     0.9687     1.0     1.0  0.9512
